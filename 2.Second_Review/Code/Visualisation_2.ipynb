# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ```
# HEATMAP
#
# ```

# %%
dataframe=pd.read_csv("BinaryData.csv")
df = pd.DataFrame(dataframe)
#df = df.drop(['Class'], axis=1)

plt.figure(figsize=(12, 6))

heatmap = sns.heatmap(df.corr(),vmin=-1, vmax=1,annot=True,cmap="Blues")
heatmap.set_title('Binary-Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
dataframe=pd.read_csv("MultiData.csv")
df = pd.DataFrame(dataframe)
#df = df.drop(['Class'], axis=1)

plt.figure(figsize=(12, 6))

heatmap = sns.heatmap(df.corr(),vmin=-1, vmax=1,annot=True,cmap="Blues")
heatmap.set_title('Multi-Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
dataframe=pd.read_csv("Binary-Kaggle.csv")
df = pd.DataFrame(dataframe)
#df = df.drop(['is_safe'], axis=1)

plt.figure(figsize=(16, 8))

heatmap = sns.heatmap(df.corr(),vmin=-1, vmax=1,annot=True,cmap="Blues")
heatmap.set_title('Binary_Kaggle-Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e0a1616a0a0> in <module>()
# ----> 1 dataframe=pd.read_csv("Binary-Kaggle.csv")
#       2 df = pd.DataFrame(dataframe)
#       3 #df = df.drop(['is_safe'], axis=1)
#       4
#       5 plt.figure(figsize=(16, 8))
#
# NameError: name 'pd' is not defined

# %%
dataframe=pd.read_csv("Well-extracted-SLI.csv")
df = pd.DataFrame(dataframe)
#new_df=df[['pH','TDS','Turbidity','Phospate','Nitrate','Iron','COD(mg/L)','Chlorine','Sodium']]
#df = df.drop(['ClassLabel-No'], axis=1)

plt.figure(figsize=(14, 6))

heatmap = sns.heatmap(df.corr(),vmin=-1, vmax=1,annot=True,cmap="Blues")
heatmap.set_title('Multi_Chengalpattu-Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
dataframe=pd.read_csv("Well-extracted-SLI.csv")
df = pd.DataFrame(dataframe)

df.head()
# Out:
#     SLI-TDS  SLI-NO2+NO3    SLI-Ca     SLI-Mg       SLI-Na       SLI-K  \
# 0  1.604651     1.705426  3.968992   2.093023   308.139535   23.255814
# 1  1.017442     0.930233  2.728682   2.325581   133.720930   11.627907
# 2  2.348837     0.775194  6.449612   3.488372   337.209302  232.558140
# 3  2.034884     0.000000  4.961240   7.906977   267.441860   23.255814
# 4  8.622093     3.720930  8.930233  14.186047  1872.093023  976.744186
#
#       SLI-Cl   SLI-SO4     SLI-F   SLI-HCO3     SLI-pH   SLI-HAR    SLI-SAR  \
# 0   2.465116  0.593023  1.209302   5.674419  11.019678  1.782946   4.959140
# 1   1.302326  1.186047  1.069767   2.837209  11.162791  1.472868   2.374102
# 2   2.465116  2.686047  2.186047   9.953488  11.305903  2.945736   4.240088
# 3   2.465116  1.430233  2.232558  12.465116  11.592129  3.720930   3.005528
# 4  18.139535  8.372093  1.953488  19.302326  11.162791  6.666667  15.696295
#
#         WQI/n  ClassLabel-No
# 0   28.343928              1
# ...

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
import numpy as np
import sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
dataframe=pd.read_csv("Well-extracted-SLI.csv")
df = pd.DataFrame(dataframe)

df_1 = df.drop(['ClassLabel-No'], axis=1)
#df_1
df_new = (df_1-df_1.mean())/df_1.std()

two_d_arr = df_new.to_numpy()
y = df['ClassLabel-No'] 
 
one_d_arr = y.to_numpy()
one_d_arr
# Out:
# array([1, 1, 1, ..., 2, 3, 4])

# %%
scaler = MinMaxScaler(feature_range=(0,20))
# fit and transform in one step
normalized = scaler.fit_transform(df)
# inverse transform
inverse = scaler.inverse_transform(normalized)

#scaler.fit(df_1)

inverse
# Out:
# array([[ 1.60465116,  1.70542636,  3.96899225, ...,  4.95913953,
#         28.34392812,  1.        ],
#        [ 1.01744186,  0.93023256,  2.72868217, ...,  2.37410233,
#         13.36583733,  1.        ],
#        [ 2.34883721,  0.7751938 ,  6.4496124 , ...,  4.24008837,
#         47.58552948,  1.        ],
#        ...,
#        [13.05813953,  9.45736434, 12.27906977, ..., 18.60465116,
#         47.93987661,  2.        ],
#        [20.49418605, 12.40310078,  9.6744186 , ...,  4.65116279,
#         46.39470666,  3.        ],
#        [24.62209302, 11.9379845 , 24.31007752, ..., 11.62790698,
#         49.3103298 ,  4.        ]])

# %%
scaler = StandardScaler()
# fit and transform the data
scaled_data = scaler.fit_transform(df_1) 

scaled_data
# Out:
# array([[-3.26485238, -3.20064398, -2.67692333, ..., -1.46154027,
#         -1.14065718, -1.54264247],
#        [-3.36949266, -3.46679295, -2.93674918, ..., -1.52387859,
#         -1.52560859, -1.76170285],
#        [-3.13223897, -3.52002275, -2.15727161, ..., -1.22777159,
#         -1.24773485, -1.2612266 ],
#        ...,
#        [-1.22384904, -0.53915424, -0.93609009, ..., -0.20854015,
#          0.89136732, -1.25604413],
#        [ 0.10124907,  0.47221186, -1.48172439, ..., -1.09374422,
#         -1.18651961, -1.27864284],
#        [ 0.83683911,  0.31252247,  1.58422072, ...,  1.73329834,
#         -0.14757615, -1.23600072]])

# %%
dataframe=pd.read_csv("Well-extracted-SLI.csv")
df = pd.DataFrame(dataframe)

x = df['SLI-F']
y = df['ClassLabel-No'] 

X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.3)

# %%
X = df[['SLI-F']]
X.shape
#X.reshape(-1, 1)
# Out:
# (10248, 1)

# %%
model = LinearRegression().fit(X, y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(X, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.021695157676744792

# %%
lm = linear_model.LinearRegression()
lm.fit(X, y) # fitting the model
lm.predict(X)
# Out:
# array([1.84065506, 1.80364265, 2.09974194, ..., 2.75362788, 2.75362788,
#        2.75362788])

# %%
lm.score(X, y)
# Out:
# 0.021695157676744792

# %%
lm.intercept_
# Out:
# 1.5198808257525154

# %%
lm.coef_
# Out:
# array([0.26525562])

# %%
preds = lm.predict(X_test)

r2_score(Y_test, preds)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-54992281f212> in <module>()
# ----> 1 preds = lm.predict(X_test)
#       2
#       3 r2_score(Y_test, preds)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# ...
